# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = r'/home/tony/Desktop/DV_homework/homework1/pitching.csv'

df = pd.read_csv(file,encoding='utf8')

# %%
df
# Out:
#         playerID nameFirst    nameLast         nameGiven  yearID  stint  \
# 0      abbotda01       Dan      Abbott  Leander Franklin    1890      1
# 1      abbeybe01      Bert       Abbey         Bert Wood    1892      1
# 2      abbeybe01      Bert       Abbey         Bert Wood    1893      1
# 3      abbeybe01      Bert       Abbey         Bert Wood    1894      1
# 4      abbeybe01      Bert       Abbey         Bert Wood    1895      2
# ...          ...       ...         ...               ...     ...    ...
# 44134  zimmejo02    Jordan  Zimmermann         Jordan M.    2014      1
# 44135  zieglbr01      Brad     Ziegler      Brad Gregory    2015      1
# 44136  zimmejo02    Jordan  Zimmermann         Jordan M.    2015      1
# 44137   zitoba01     Barry        Zito     Barry William    2015      1
# 44138   zychto01      Tony        Zych     Anthony Aaron    2015      1
#
#       teamID lgID   W   L  ...  IBB    WP  HBP  BK    BFP    GF    R   SH  \
# ...

# %%
df.columns
# Out:
# Index(['playerID', 'nameFirst', 'nameLast', 'nameGiven', 'yearID', 'stint',
#        'teamID', 'lgID', 'W', 'L', 'G', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H',
#        'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP',
#        'GF', 'R', 'SH', 'SF', 'GIDP'],
#       dtype='object')

# %%
pitchers = df.loc[df.yearID == 2015].sort_values(by='nameLast')
pitchers[['nameLast','yearID']]
# Out:
#          nameLast  yearID
# 341       Aardsma    2015
# 342          Abad    2015
# 343        Achter    2015
# 344         Adams    2015
# 345        Adcock    2015
# ...           ...     ...
# 44135     Ziegler    2015
# 44136  Zimmermann    2015
# 44137        Zito    2015
# 44138        Zych    2015
# 9437       deGrom    2015
#
# [809 rows x 2 columns]

# %%
pitchers_ERA = pitchers.sort_values('ERA',ascending=True)
pitchers_ERA[['nameLast','ERA']]
# Out:
#         nameLast   ERA
# 3491     Blevins   0.0
# 33242      Reyes   0.0
# 32592  Rasmussen   0.0
# 32580    Ramirez   0.0
# 32272     Raburn   0.0
# ...          ...   ...
# 8206     Cornely  36.0
# 4987      Burawa  54.0
# 27583     Morris  67.5
# 34372     Rondon  90.0
# 14772  Greenwood   NaN
#
# [809 rows x 2 columns]

# %%
pitchers.groupby('teamID')['ERA'].agg(total='count').reset_index()['total']
# g = df_agg['count'].groupby(level=0, group_keys=False)
# res = g.apply(lambda x: x.order(ascending=False))
# Out:
# 0     27
# 1     37
# 2     22
# 3     26
# 4     24
# 5     29
# 6     28
# 7     27
# 8     30
# 9     27
# 10    24
# 11    24
# 12    24
# 13    31
# 14    29
# 15    26
# 16    24
# 17    33
# 18    26
# 19    30
# 20    30
# 21    21
# 22    26
# 23    28
# 24    21
# 25    22
# 26    27
# 27    31
# 28    28
# 29    26
# Name: total, dtype: int64

# %%
dir(df_agg)
# Out:
# ['BAOpp',
#  'BB',
#  'BFP',
#  'BK',
#  'CG',
#  'ER',
#  'ERA',
#  'G',
#  'GF',
#  'GIDP',
#  'GS',
#  'H',
#  'HBP',
#  'HR',
#  'IBB',
#  'IPouts',
#  'L',
#  'R',
#  'SF',
#  'SH',
#  'SHO',
#  'SO',
#  'SV',
#  'W',
#  'WP',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_frame',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-30594828e202> in <module>
# ----> 1 df_agg[['nameLast','ERA']]
#
# ~/anaconda3/envs/forXGBoost/lib/python3.7/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1611                 stacklevel=2,
#    1612             )
# -> 1613         return super().__getitem__(key)
#    1614
#    1615     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/anaconda3/envs/forXGBoost/lib/python3.7/site-packages/pandas/core/base.py in __getitem__(self, key)
#     222     def __getitem__(self, key):
#     223         if self._selection is not None:
# --> 224             raise IndexError(f"Column(s) {self._selection} already selected")
#     225
#     226         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass, np.ndarray)):
#
# IndexError: Column(s) ['nameLast', 'ERA'] already selected
