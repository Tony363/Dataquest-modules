# %% [markdown]
# # Introduction

# %% [markdown]
# ## Content
# Information on economic data related to mortgages, home equity loans, second mortgages, family income, rent-statistics and bad debts in different states in USA.
#
# ## Acknowledgements
# Source: The data set was found in www.kaggle.com and was released by Golden Oak Research Group 1. This is very insightful US mortgage data with  vast USA Statistics by states.
#
#
# ## Group 9
# Prepared by Denis Dzhindo, Indra Chatterjee
#
# ## Inspiration
# United states is a land of golden opportunity where we all can make our dream come true.  We tried to analyze from the dataset where most people own homes in the country, where most people rent and where most people got the bad debbt like second mortgage or home equity loan. We also found which states have the highest high school degress and  where most people have the highest family savings as well as where we see investment opportunities! Sky is the limit in United States if you would like to pursure your dream.

# %% [markdown]
# # Dataset Information

# %% [markdown]
#  ### OVERVIEW
# 1. Savings after mortgage: Its a variable we have created which we use to calculate the difference of Family Mean Income and Mortgage Payment.
# Savings after mortgage = family_mean - hc_mortgage_mean*12
# 2. Savings after Rent:Its a variable we have created which we use to calculate the difference of Family Mean Income and Rent Payment.
# Savings after Rent = family_mean - rent_mean*12
# 3. Bad Debt: Its a variable we have created which we use to calculate the sum of second mortgage and home equity mortgage. bad_debt = second_mortgage + home_equity
# 4. Household Income Household Income includes the sum of the householder and all other individuals +15 years whom reside in the household, whether they are related to the householder or not. Because many households consist of only one person, average household income is usually less than average family income. Although the household income statistics cover the past 12 months, the characteristics of individuals and the composition of households refer to the time of interview. Thus, the income of the household does not include amounts received by individuals who were members of the household during all or part of the past 12 months if these individuals no longer resided in the household at the time of interview. Similarly, income amounts reported by individuals who did not reside in the household during the past 12 months but who were members of the household at the time of interview are included. However, the composition of most households was the same during the past 12 months as at the time of interview.
# 5. Family Income Family income includes, the incomes of all members +15 years of age related to the householder are summed and treated as a single amount. Although the family income statistics cover the past 12 months, the characteristics of individuals and the composition of families refer to the time of interview. Thus, the income of the family does not include amounts received by individuals who were members of the family during all or part of the past 12 months if these individuals no longer resided with the family at the time of interview. Similarly, income amounts reported by individuals who did not reside with the family during the past 12 months but who were members of the family at the time of interview are included. However, the composition of most families was the same during the past 12 months as at the time of interview.
# LOCATION FIELD DEFINITIONS
# 6. UID Type: Character Description: The ID of the location of which you are analyzing. ID location compatible across all Golden Oak Research Locations. Example: 0101909
# 7. STATEID Type: Character Description: The state code reported by the U.S. Census Bureau for the specified geographic location. Example: ‘01’ (State: Alabama)
# 8. BLOCKID Type: Character Description: Block ID of tract. If there is no specified block id the location is then a tract. The maximum number of blocks for any given track is 9. Example: ‘3’
# 9. state Type: Character Description: The state name reported by the U.S. Census Bureau for the specified geographic location. Example: Alabama
# 10. state_ab Type: Character Description: The abbreviated state name reported by the U.S. Census Bureau for the specified geographic location. Example: AL
# 11. county Type: Character Description: The county name reported by the U.S. Census Bureau for the specified geographic location. Example: Calhoun County
# 12. city Type: Character Description: The closest city name reported by the U.S. Education Department by the closest school relative to the Census Location. Example: Alexandria
# 13. place Type: Character (Categorical) Description: The place name reported by the U.S. Census Bureau for the specified geographic location. Example: Alexandria
# 14. type Type: Character (Categorical) Description: The place Type reported by the U.S. Census Bureau for the specified geographic location. Example: CPD
# 15. primary Type: Character (Categorical) Description: Defines whether the location is a tract location or a block group. Example: track
# 16. zip_code Type: Character Description: The closest zip code reported by the U.S. Education Department by the closest school relative to the Census Location. Example: 36250
# 17. area_code Type: Character Description: The area code reported by the U.S. Census Bureau of the closest geographic location with area code information. Example: 256
# 18. lat : The latitude of geographic location. Example: 33.760819
# 19. lng : The longitude of geographic location. Example: 33.760819
# 20. ALand : The Square area of land at the geographic or track location. Example: 28834974
# 21. AWater : The Square area of water at the geographic or track location. Example: 33099
# 22. pop : Male & female population of geographic location Example: -86.872008
# 23. male_pop : Male population of geographic location. Example: -86.872008
# 24. female_pop : female population of geographic location. Example: -86.872008
# STATISTIC FIELD DEFINITIONS
# 1. second_mortgage : percent of houses with a second mortgage Example: 92686
# 2. home_equity : Percentage of homes with a home equity loan. Example: 35735
# 3. home_equity_second_mortgage : Percentage of homes with a second mortgage and home equity loan. Example: 258
# 4. home_equity_second_mortgage : Percentage of homes with a second mortgage and home equity loan. Example: 0.0138
# 5. debt : Percentage of homes with some type of debt. Example: 258
# 6. second_mortgage_cdf : Cumulative distribution value of one minus the percentage of homes with a second mortgage. The value is used as a performance feature. Example: 258
# 7. home_equity_cdf : Cumulative distribution value of one minus the percentage of homes with a home equity loan. The value is used as a performance feature. Example: 258
# 8. debt_cdf : Cumulative distribution value of one minus the percentage of homes with any home related debt. The value is used as a performance feature. Example: 258
# 9. hs_degree : Percentage of people with at least high school degree. Example: 258
# 10. hs_degree_male : Percentage of males with at least high school degree. Example: 258
# 11. hs_degree_female : Percentage of females with at least high school degree. Example: 258
# 12. hc_mortgage_mean : The mean Monthly Mortgage and Owner Costs of specified geographic location. Example: 1208
# 13. hc_mortgage_median : The median Monthly Mortgage and Owner Costs of the specified geographic location. Example: 16686
# 14. hc_mortgage_stdev : The standard deviation of the Monthly Mortgage and Owner Costs for a specified geographic location. Example: 568
# 15. hc_mortgage_sample : The number of samples used in the statistical calculations Example: 3
# 16. hc_mortgage_sample_weight : The number of samples used in the statistical calculations Example: 3
# 17. hc_mean : The mean Monthly Owner Costs of specified geographic location. Example: 93216
# 18. hc_median : The median Monthly Owner Costs of a specified geographic location. Example: 35735
# 19. hc_stdev : The standard deviation of the Monthly Owner Costs of a specified geographic location. Example: 92686
# 20. hc_samples : The samples used in the calculation of the Monthly Owner Costs statistics. Example: 35735
# 21. hc_sample_weight : The samples used in the calculation of the Monthly Owner Costs statistics. Example: 35735
# 22. rent_mean : The mean gross rent of the specified geographic location. Example: 734
# 23. rent_median : The mean gross rent of the specified geographic location. Example: 724
# 24. rent_stdev : The standard deviation of the gross rent for the specified geographic location. Example: 232
# 25. rent_samples : The number of gross rent records used in the statistical calculations Example: 355
# 26. rent_sample_weight : The sum of gross rent weight used in calculations. Example: 355
# 27. rent_gt_10  : The empirical distribution value that an individual’s rent will be greater than 10% of their household income in the past 12 months. Example: 0.94558
# 28. rent_gt_15  : The empirical distribution value that an individual’s rent will be greater than 15% of their household income in the past 12 months. Example: 0.83673
# 29. rent_gt_20  : The empirical distribution value that an individual’s rent will be greater than 20% of their household income in the past 12 months. Example: 0.81633
# 30. rent_gt_25  : The empirical distribution value that an individual’s rent will be greater than 25% of their household income in the past 12 months. Example: 0.63265
# 31. rent_gt_30  : The empirical distribution value that an individual’s rent will be greater than 30% of their household income in the past 12 months. Example: 0.47619
# 32. rent_gt_35  : The empirical distribution value that an individual’s rent will be greater than 35% of their household income in the past 12 months. Example: 0.47619
# 33. rent_gt_40  : The empirical distribution value that an individual’s rent will be greater than 40% of their household income in the past 12 months. Example: 0.31293
# 34. rent_gt_50  : The empirical distribution value that an individual’s rent will be greater than 50% of their household income in the past 12 months. Example: 0.16327
# 35. rent_universe_samples  : The size of the renter-occupied housing units sampled universe for the calculations. Example: 355
# 36. rent_used_samples : The number of samples used in the household income by gross rent as percentage of income in the past 12 months calculation. Example: 355
# 37. family_income_mean : The mean family income of the specified geographic location. Example: 93216
# 38. family_income_median : The median family income of the specified geographic location. Example: 92686
# 39. family_income_stdev : The standard deviation of the family income for the specified geographic location. Example: 35735
# 40. family_income_families : The number of families used in the statistical calculations Example: 258
# 41. hi_mean : The mean household income of the specified geographic location. Example: 93216
# 42. hi_median : The median household income of the specified geographic location. Example: 92686
# 43. hi_stdev : The standard deviation of the household income for the specified geographic location. Example: 35735
# 44. hi_samples : The number of households used in the statistical calculations Example: 258
# 45. hi_sample_weight : The number of households weighted used in the statistical calculations

# %% [markdown]
# ### We will be doing cleanup from above 69 columns and eliminate  columns as and when needed when we awe run differnt analytics or decession tree

# %% [markdown]
# ## Import the mortgage dataset

# %%
# Introduction# print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import seaborn as sns
import numpy as np
# %pylab inline

import sklearn as sk
import sklearn.tree as tree
from IPython.display import Image  
import pydotplus
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# import additional packages
import re, sklearn, warnings, math, pandas as pd, numpy as np
import seaborn as sns, matplotlib.pyplot as plt, matplotlib
import plotly.graph_objs as go, plotly.offline as py, plotly.tools as tls
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# import settings
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 12})
py.init_notebook_mode(connected=True)
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('real_estate_db.csv', encoding = 'ISO-8859–1')

# %%
df.head(1)
len(df)
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID   state state_ab      city  \
# 0  220336      NaN       140        16        2  Alaska       AK  Unalaska
#
#            place  type  ... female_age_mean  female_age_median  \
# 0  Unalaska City  City  ...        32.78177           31.91667
#
#    female_age_stdev  female_age_sample_weight  female_age_samples  pct_own  \
# 0          19.31875                 440.46429              1894.0  0.25053
#
#    married  married_snp  separated  divorced
# 0  0.47388      0.30134    0.03443   0.09802
#
# [1 rows x 80 columns]
# 39030

# %%
df.columns.unique()
# Out:
# Index(['UID', 'BLOCKID', 'SUMLEVEL', 'COUNTYID', 'STATEID', 'state',
#        'state_ab', 'city', 'place', 'type', 'primary', 'zip_code', 'area_code',
#        'lat', 'lng', 'ALand', 'AWater', 'pop', 'male_pop', 'female_pop',
#        'rent_mean', 'rent_median', 'rent_stdev', 'rent_sample_weight',
#        'rent_samples', 'rent_gt_10', 'rent_gt_15', 'rent_gt_20', 'rent_gt_25',
#        'rent_gt_30', 'rent_gt_35', 'rent_gt_40', 'rent_gt_50',
#        'universe_samples', 'used_samples', 'hi_mean', 'hi_median', 'hi_stdev',
#        'hi_sample_weight', 'hi_samples', 'family_mean', 'family_median',
#        'family_stdev', 'family_sample_weight', 'family_samples',
#        'hc_mortgage_mean', 'hc_mortgage_median', 'hc_mortgage_stdev',
#        'hc_mortgage_sample_weight', 'hc_mortgage_samples', 'hc_mean',
#        'hc_median', 'hc_stdev', 'hc_samples', 'hc_sample_weight',
#        'home_equity_second_mortgage', 'second_mortgage', 'home_equity', 'debt',
#        'second_mortgage_cdf', 'home_equity_cdf', 'debt_cdf', 'hs_degree',
#        'hs_degree_male', 'hs_degree_female', 'male_age_mean',
#        'male_age_median', 'male_age_stdev', 'male_age_sample_weight',
#        'male_age_samples', 'female_age_mean', 'female_age_median',
#        'female_age_stdev', 'female_age_sample_weight', 'female_age_samples',
#        'pct_own', 'married', 'married_snp', 'separated', 'divorced'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 67815

# %% [markdown]
# ## Graphically locate highest Second Mortgage locations in the Country

# %%
# calculate basic data
df['pop_density'] = df['pop'].values/ df['ALand'].values# calculate population density

# calculate average median age
t_male_yrs       = df.male_age_median.values*df.male_pop.values
t_female_yrs     = df.female_age_median.values*df.female_pop.values 
df['age_median'] = (t_male_yrs + t_female_yrs)/(df.male_pop.values + df.female_pop.values)

# %%
# obtain top x = 2,000 location with the highest second mortgage rates
term = 'second_mortgage'; scale = 1000; places = []; 
limits = [(0,399),(400,799),(800,1199),(1200,1599),(1600,2000)]
colors = ["rgb(0,116,217)","rgb(255,65,54)","rgb(133,20,75)","rgb(255,133,27)","rgb(76, 199, 144)"]
df_pop = df[df['pct_own']> .1][[term,'place','lat','lng','pct_own','pop','age_median']].sort_values(by=term, ascending=False)
df_pop['text'] = df_pop.place + '<br>Second Mortgage ' + round(df_pop[term]*1e2,4).astype(str) + '%'

# create colors for plot
for i in range(len(limits)): 
    nme = '{0} - {1}'.format(limits[i][0],limits[i][1]); df_sub = df_pop[limits[i][0]:limits[i][1]]; places.append(dict(type = 'scattergeo', 
    locationmode = 'USA-states', lon = df_sub.lng, lat = df_sub.lat, text = df_sub.text,marker = dict(color = colors[i],
    size = list(map(lambda x: 15 + x*scale,df_sub[term].values)),line = dict(width=0.5, color='rgb(40,40,40)'), sizemode = 'area'), name = nme))

# set layout data
layout = dict(title = '<br>Top 2,000 Highest Second Mortgage Locations<br>', showlegend = True,geo = dict(
         scope='usa', projection=dict( type='albers usa' ),showland = True,landcolor = 'rgb(217, 217, 217)',
         subunitwidth=1,countrywidth=1, subunitcolor="rgb(255, 255, 255)", countrycolor="rgb(255, 255, 255)"))

# display plot
fig = dict( data=places, layout=layout )
py.iplot( fig, validate=False, filename='d3-mortgage',show_link=False,config={'displayModeBar':False,'showLink': False})
# Out:
# <div>
#
#
#             <div id="55b31031-49cd-4fed-ae3f-9b6ab334dd0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("55b31031-49cd-4fed-ae3f-9b6ab334dd0d")) {
#                     Plotly.newPlot(
#                         '55b31031-49cd-4fed-ae3f-9b6ab334dd0d',
#                         [{"lat": [37.297357399999996, 42.254261799999995, 35.6556953, 40.7518089, 39.12727279999999, 28.029063300000004, 41.9672885, 39.0069338, 41.9066403, 42.71420820000001, 43.067063299999994, 34.0931841, 39.953811200000004, 37.656228999999996, 40.8832885, 39.121315700000004, 32.8003476, 38.822025399999994, 38.5002139, 42.28480029999999, 38.819171399999995, 39.5094376, 38.2947649, 39.9053744, 41.5270157, 42.39712720000001, 33.943003499999996, 38.2470347, 38.8499425, 41.7677281, 34.1853923, 41.783468, 34.1039593, 45.4454048, 33.9555895, 38.8786133, 28.533263199999997, 33.724903600000005, 33.908848799999994, 35.128587599999996, 38.8120774, 41.5148104, 32.2955885, 43.9728571, 47.2401479, 38.971338, 42.3244316, 34.363620000000004, 33.5651234, 36.8988703, 39.6599172, 28.023056300000004, 33.5552376, 41.79415170000001, 26.0073086, 39.7756533, 40.9199667, 39.859951, 41.7454851, 40.6943396, 42.2826649, 37.832642299999996, 38.8328939, 41.723515500000005, 39.1331602, 40.6130385, 35.092118299999996, 33.8796686, 39.37924829999999, 37.776064899999994, 33.989555700000004, 40.8377899, 40.8377899, 41.7395016, 35.9901296, 32.6599903, 34.1109412, 42.142745500000004, 40.6406399, 44.974769, 39.1524277, 38.6614448, 33.924708100000004, 42.72897570000001, 39.9527732, 37.356210499999996, 35.1952808, 36.16242929999999, 28.520498800000002, 38.5916036, 40.7594056, 40.066865299999996, 47.6199882, 33.7088571, 34.0432749, 32.1882903, 30.236133600000002, 34.439452100000004, 40.7821699, 37.0986965, 45.6548641, 34.435608, 39.135554299999995, 34.253678799999996, 34.1494929, 40.938853200000004, 41.1131233, 41.636211100000004, 37.539712200000004, 38.8879464, 39.3834988, 38.0163196, 38.7222559, 40.65418029999999, 36.318979600000006, 34.9148169, 40.5942315, 38.832772, 37.804675399999994, 38.6037792, 40.385902, 37.050310499999995, 34.2804584, 40.1233788, 47.6134675, 45.5188106, 40.8897429, 41.6639299, 41.705247799999995, 32.7451404, 41.741561499999996, 32.8924948, 45.527539000000004, 42.7224295, 41.7902101, 37.7741755, 35.998208899999995, 45.4992015, 34.012268799999994, 40.7955828, 41.7617135, 34.0671467, 38.846390299999996, 39.6754541, 41.8085114, 41.259119500000004, 41.4581171, 41.835608, 39.1886045, 33.1732234, 39.1372261, 45.13485479999999, 38.7094156, 30.442819800000002, 47.5383594, 41.7944972, 33.7789729, 37.7344919, 33.7452198, 45.0360622, 38.7240552, 39.0901783, 25.910425, 34.096208700000005, 37.2980229, 32.7840087, 33.801900399999994, 30.3465716, 40.4253305, 33.9546932, 41.987226, 43.1866246, 35.53258220000001, 43.563675, 47.2287315, 38.945693799999994, 41.1706268, 34.960759100000004, 38.86885720000001, 34.2409046, 37.7109995, 36.9880686, 36.8444256, 39.3785915, 39.9174144, 35.281548, 36.0446391, 38.9349477, 41.9376356, 33.655237899999996, 34.09790770000001, 38.1295441, 33.7247482, 33.8440428, 25.864262600000004, 33.3305333, 38.5419331, 38.2665083, 33.075514500000004, 44.9767007, 41.5416464, 34.2247342, 33.8089196, 34.264058899999995, 40.4427091, 32.7898054, 41.621989299999996, 33.5876988, 41.54496339999999, 40.679176399999996, 42.0227059, 33.82164229999999, 39.157612, 38.890639799999995, 42.3666766, 35.7849873, 42.0298213, 41.051989, 42.682308899999995, 33.7538839, 34.1316179, 40.6884061, 40.8384785, 38.0127453, 34.152183, 33.7069847, 33.4281516, 32.476876399999995, 40.6986408, 34.0685435, 40.7556398, 43.3343356, 39.0087272, 36.78732670000001, 25.606451999999997, 40.6701918, 41.6205331, 40.753794799999994, 40.472764399999996, 33.6278555, 47.8581251, 36.2541516, 38.8313107, 47.399399, 42.310936600000005, 33.2130024, 33.9660089, 40.7842611, 33.65181629999999, 33.7548958, 41.48161270000001, 34.8631405, 33.1732652, 40.345487, 43.049339200000006, 33.8647762, 40.914559999999994, 27.9118994, 37.920601700000006, 34.0813583, 45.5454185, 33.771918, 39.0666053, 44.97144, 39.0912204, 35.9949426, 38.8396609, 40.0416936, 40.658007399999995, 36.8973185, 33.914104200000004, 29.935141700000003, 34.1392052, 30.1702766, 39.537403399999995, 38.0093047999999 ...

# %% [markdown]
# ## Cleanup Data in below step by step process where we also have eliminated duplicate or bad records

# %%
df.drop(['used_samples', 'universe_samples', 'hc_mortgage_median','family_median',\
         'hi_median','pop','female_pop','hc_median','female_age_samples','UID','hi_mean',\
         'female_age_median','hi_stdev','male_age_median','hc_samples','rent_median',\
         'female_age_sample_weight','male_age_sample_weight','male_age_sample_weight',\
         'rent_gt_35','rent_gt_40','rent_stdev','rent_gt_50','rent_gt_10','rent_gt_15',\
         'rent_gt_20','rent_gt_25','rent_sample_weight','type','hc_sample_weight','male_age_samples','area_code',\
         'hc_stdev','rent_sample_weight','family_sample_weight','state_ab','female_age_stdev','rent_samples',\
         'hi_sample_weight','hc_mortgage_sample_weight','second_mortgage_cdf','home_equity_cdf',\
         'COUNTYID','STATEID','SUMLEVEL','ALand','AWater','hi_samples',\
         'hc_mortgage_stdev','hc_mortgage_samples','hc_mean','male_age_stdev',\
         'home_equity_second_mortgage','family_stdev','BLOCKID','primary','lat','lng','place','male_pop',\
         'rent_gt_30'], axis=1, inplace=True)

# %%
df.columns.unique()
# Out:
# Index(['state', 'city', 'zip_code', 'rent_mean', 'family_mean',
#        'family_samples', 'hc_mortgage_mean', 'second_mortgage', 'home_equity',
#        'debt', 'debt_cdf', 'hs_degree', 'hs_degree_male', 'hs_degree_female',
#        'male_age_mean', 'female_age_mean', 'pct_own', 'married', 'married_snp',
#        'separated', 'divorced', 'pop_density', 'age_median'],
#       dtype='object')

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 2  Alaska         Jber     99505  2071.30766   67678.50158          1858.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  ...  \
# 0        2266.22562          0.01408      0.02817  0.72770  ...
# 1        2485.10777          0.06078      0.07407  0.75689  ...
# 2               NaN          0.00000      0.00000  0.00000  ...
# 3        2289.79186          0.00000      0.04469  0.78212  ...
# 4        1904.16410          0.04083      0.08514  0.67246  ...
#
#    hs_degree_female  male_age_mean  female_age_mean  pct_own  married  \
# 0           0.82940       38.45838         32.78177  0.25053  0.47388
# 1           0.91503       37.26216         38.97956  0.94989  0.52381
# 2           0.98408       21.96291         22.20427  0.00759  0.50459
# 3           0.84871       35.81912         37.00750  0.20247  0.44428
# 4           0.94669       34.13110         34.96611  0.56936  0.51034
#
#    married_snp  separated  divorced  pop_density  age_median
# 0      0.30134    0.03443   0.09802     0.000002   36.243001
# 1      0.01777    0.00782   0.13575     0.000007   39.507468
# 2      0.06676    0.01000   0.01838     0.000032   22.624601
# 3      0.05933    0.00000   0.21563     0.000818   34.000000
# 4      0.08315    0.06731   0.08711     0.003022   30.935701
#
# [5 rows x 23 columns]

# %%
for x in df.columns:
    print (x + ':' + str(df[x].nunique()))
# Out:
# state:52
# city:8172
# zip_code:15098
# rent_mean:38220
# family_mean:38387
# family_samples:2881
# hc_mortgage_mean:37939
# second_mortgage:8856
# home_equity:17375
# debt:25932
# debt_cdf:27680
# hs_degree:22289
# hs_degree_male:22592
# hs_degree_female:21533
# male_age_mean:38090
# female_age_mean:38060
# pct_own:29602
# married:26133
# married_snp:11637
# separated:6893
# divorced:15838
# pop_density:38531
# age_median:38375

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 2  Alaska         Jber     99505  2071.30766   67678.50158          1858.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  ...  \
# 0        2266.22562          0.01408      0.02817  0.72770  ...
# 1        2485.10777          0.06078      0.07407  0.75689  ...
# 2               NaN          0.00000      0.00000  0.00000  ...
# 3        2289.79186          0.00000      0.04469  0.78212  ...
# 4        1904.16410          0.04083      0.08514  0.67246  ...
#
#    hs_degree_female  male_age_mean  female_age_mean  pct_own  married  \
# 0           0.82940       38.45838         32.78177  0.25053  0.47388
# 1           0.91503       37.26216         38.97956  0.94989  0.52381
# 2           0.98408       21.96291         22.20427  0.00759  0.50459
# 3           0.84871       35.81912         37.00750  0.20247  0.44428
# 4           0.94669       34.13110         34.96611  0.56936  0.51034
#
#    married_snp  separated  divorced  pop_density  age_median
# 0      0.30134    0.03443   0.09802     0.000002   36.243001
# 1      0.01777    0.00782   0.13575     0.000007   39.507468
# 2      0.06676    0.01000   0.01838     0.000032   22.624601
# 3      0.05933    0.00000   0.21563     0.000818   34.000000
# 4      0.08315    0.06731   0.08711     0.003022   30.935701
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (39030, 23)

# %%
df.isna().sum().sum()
# Out:
# 8148

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (38131, 23)

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  ...  \
# 0        2266.22562          0.01408      0.02817  0.72770  ...
# 1        2485.10777          0.06078      0.07407  0.75689  ...
# 3        2289.79186          0.00000      0.04469  0.78212  ...
# 4        1904.16410          0.04083      0.08514  0.67246  ...
# 5        2060.45716          0.02897      0.05164  0.74685  ...
#
#    hs_degree_female  male_age_mean  female_age_mean  pct_own  married  \
# 0           0.82940       38.45838         32.78177  0.25053  0.47388
# 1           0.91503       37.26216         38.97956  0.94989  0.52381
# 3           0.84871       35.81912         37.00750  0.20247  0.44428
# 4           0.94669       34.13110         34.96611  0.56936  0.51034
# 5           0.84932       29.23608         33.63770  0.45011  0.39429
#
#    married_snp  separated  divorced  pop_density  age_median
# 0      0.30134    0.03443   0.09802     0.000002   36.243001
# 1      0.01777    0.00782   0.13575     0.000007   39.507468
# 3      0.05933    0.00000   0.21563     0.000818   34.000000
# 4      0.08315    0.06731   0.08711     0.003022   30.935701
# 5      0.04615    0.02418   0.10242     0.002620   27.102687
#
# [5 rows x 23 columns]

# %%
df.groupby(['state'])[ 'rent_mean'].max().sort_values(ascending=False).nlargest(5)
# Out:
# state
# Michigan      3962.34229
# Hawaii        3962.34229
# California    3962.34229
# Florida       3962.34229
# Texas         3962.34229
# Name: rent_mean, dtype: float64

# %% [markdown]
# ### Excluding records where rent_mean is 3962.34229 due to bad record

# %%
df[df.rent_mean >= 3962]
# Out:
#             state            city  zip_code   rent_mean   family_mean  \
# 3906   California  Trabuco Canyon     92679  3962.34229  182176.81010
# 9065      Florida      Boca Raton     33431  3962.34229  132927.45197
# 10781      Hawaii        Honolulu     96825  3962.34229  169995.63074
# 17689    Michigan    Grand Rapids     49546  3962.34229  145860.03627
# 25086    New York       Pittsford     14534  3962.34229  144613.97413
# 32926   Tennessee       Brentwood     37027  3962.34229  170844.23224
# 35367       Texas       Southlake     76092  3962.34229  181031.60671
#
#        family_samples  hc_mortgage_mean  second_mortgage  home_equity  \
# 3906           1159.0        3555.34215          0.05241      0.34880
# 9065            999.0        2797.17943          0.03707      0.18451
# 10781           410.0        3328.96730          0.02570      0.13490
# 17689          1907.0        2335.32485          0.05437      0.14498
# 25086          1280.0        2253.67953          0.04245      0.17626
# 32926          1101.0        2915.11370          0.00000      0.21422
# 35367          2056.0        3850.33162          0.02011      0.17093
#
#           debt  ...  hs_degree_female  male_age_mean  female_age_mean  \
# 3906   0.85223  ...           0.98050       41.49066         37.57647
# 9065   0.64415  ...           0.98336       41.85668         46.04715
# 10781  0.70021  ...           1.00000       47.08813         50.94102
# 17689  0.63569  ...           0.99379       40.49827         39.64304
# 25086  0.74101  ...           1.00000       37.81392         38.78849
# 32926  0.82133  ...           1.00000       38.70892         34.60305
# 35367  0.71069  ...           1.00000       36.50816         36.30341
#
#        pct_own  married  married_snp  separated  divorced  pop_density  \
# 3906   0.91434  0.75512      0.00858    0.00000   0.06205     0.000355
# 9065   0.98981  0.71307      0.01083    0.00077   0.07657     0.001117
# 10781  0.95153  0.76515      0.04924    0.00758   0.05492     0.001144
# 17689  0.97591  0.65323      0.00000    0.00000   0.03629     0.000081
# 25086  0.99211  0.83355      0.01459    0.00729   0.00531     0.000425
# 32926  0.96276  0.76459      0.00268    0.00000   0.00268     0.000367
# 35367  0.95863  0.74449      0.02652    0.00523   0.03362     0.000823
#
#        age_median
# 3906    44.616405
# 9065    48.657726
# 10781   55.855907
# 17689   43.708175
# 25086   43.507059
# 32926   41.424741
# 35367   42.591122
#
# [7 rows x 23 columns]

# %%
df.shape
# Out:
# (38131, 23)

# %%
df_1_rent = df[(df.rent_mean <= 3962) ]

# %% [markdown]
# #### Highest Rents

# %%
df_1_rent.groupby(['state'])[ 'rent_mean'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# Hawaii                  1676.953394
# California              1468.759124
# District of Columbia    1447.610589
# Maryland                1404.604603
# New Jersey              1392.093929
# Name: rent_mean, dtype: float64

# %% [markdown]
# #### Lowest Rents

# %%
df_1_rent.groupby(['state'])[ 'rent_mean'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico      524.685247
# West Virginia    674.666645
# South Dakota     676.777788
# Arkansas         713.879645
# Kentucky         736.234062
# Name: rent_mean, dtype: float64

# %% [markdown]
# #### Highest Mortgage

# %%
df_1_rent.groupby(['state'])[ 'hc_mortgage_mean'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# New Jersey              2424.453481
# Hawaii                  2347.603958
# New York                2227.899387
# District of Columbia    2223.340155
# California              2211.240060
# Name: hc_mortgage_mean, dtype: float64

# %% [markdown]
# #### Lowest Mortgage

# %%
df_1_rent.groupby(['state'])[ 'hc_mortgage_mean'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico       964.908401
# West Virginia    1058.253326
# Arkansas         1108.327466
# Mississippi      1122.346234
# Indiana          1137.906877
# Name: hc_mortgage_mean, dtype: float64

# %%
df_1_rent.groupby(['state'])[ 'family_mean'].max().sort_values(ascending=False).nlargest(10)
# Out:
# state
# Maryland                242857.14286
# Pennsylvania            242857.14286
# New York                218606.73230
# District of Columbia    208969.99389
# Virginia                207095.08993
# New Jersey              206839.09096
# Connecticut             206207.49257
# California              201343.78937
# Texas                   201184.78936
# Massachusetts           199730.35283
# Name: family_mean, dtype: float64

# %% [markdown]
# ### Excluding records where family_mean is 242857.1429 due to bad record

# %%
df_2_rent_family = df_1_rent[df_1_rent.family_mean <= 242857]

# %% [markdown]
# #### Highest Family Income

# %%
df_2_rent_family.groupby(['state'])[ 'family_mean'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    107592.563765
# Connecticut             104065.580760
# Maryland                100806.897651
# New Jersey              100460.310183
# Massachusetts            98465.286202
# Name: family_mean, dtype: float64

# %% [markdown]
# #### Lowest Family Income

# %%
df_2_rent_family.groupby(['state'])[ 'family_mean'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico      33812.979647
# Mississippi      59518.695622
# Arkansas         63939.536360
# West Virginia    65108.786481
# Alabama          65183.236789
# Name: family_mean, dtype: float64

# %%
pd.set_option('display.max_columns',100)

# %%
df_2_rent_family.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median
# 0     0.000002   36.243001
# 1     0.000007   39.507468
# 3     0.000818   34.000000
# 4     0.003022   30.935701
# 5     0.002620   27.102687

# %%
df_2_rent_family['savings_after_rent'] = (df_2_rent_family.family_mean - df_2_rent_family.rent_mean*12)

# %%
df_2_rent_family['savings_after_mortgage'] = (df_2_rent_family.family_mean - df_2_rent_family.hc_mortgage_mean*12)

# %%
df_2_rent_family.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median  savings_after_rent  savings_after_mortgage
# 0     0.000002   36.243001         97935.24581             87135.49721
# 1     0.000007   39.507468        120469.37537            118820.41505
# 3     0.000818   34.000000         67334.90414             51182.89214
# 4     0.003022   30.935701         64507.04066             58131.20810
# 5     0.002620   27.102687         68716.04329             60205.86121

# %% [markdown]
# #### Highest Savings after Rent

# %%
df_2_rent_family.groupby(['state'])[ 'savings_after_rent'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    90221.236698
# Connecticut             88249.030220
# Maryland                83944.926416
# Massachusetts           83833.035929
# New Jersey              83755.183030
# Name: savings_after_rent, dtype: float64

# %% [markdown]
# #### Highest Savings after Mortgage

# %%
df_2_rent_family.groupby(['state'])[ 'savings_after_mortgage'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    80912.481900
# Connecticut             77783.967187
# Maryland                76861.985410
# Massachusetts           72730.960291
# Virginia                72195.846212
# Name: savings_after_mortgage, dtype: float64

# %% [markdown]
# #### Lowest Savings after Rent

# %%
df_2_rent_family.groupby(['state'])[ 'savings_after_rent'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico      27516.756681
# Mississippi      50656.156528
# Arkansas         55372.980621
# Alabama          56029.307135
# West Virginia    57012.786744
# Name: savings_after_rent, dtype: float64

# %% [markdown]
# #### Lowest Savings after Mortgage

# %%
df_2_rent_family.groupby(['state'])[ 'savings_after_mortgage'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico    22234.078834
# Mississippi    46050.540818
# Arkansas       50639.606767
# Alabama        50859.674746
# Kentucky       52180.381566
# Name: savings_after_mortgage, dtype: float64

# %% [markdown]
# #### Highest Percent owner households

# %%
df_2_rent_family.groupby(['state'])[ 'pct_own'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# Maine            0.741576
# Vermont          0.741386
# Iowa             0.733083
# Minnesota        0.725241
# West Virginia    0.723525
# Name: pct_own, dtype: float64

# %% [markdown]
# # Dennis to add Graph here

# %%
df_Maine = df_2_rent_family[df_2_rent_family.state=='Maine']
df_Maine.head(2)
# Out:
#        state    city  zip_code  rent_mean  family_mean  family_samples  \
# 17056  Maine  Auburn      4210  562.92812  36041.33943           226.0
# 17057  Maine  Auburn      4210  706.71217  55889.66140           540.0
#
#        hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 17056        1386.29239           0.0814      0.16279  0.87209   0.06303
# 17057        1208.53512           0.0000      0.06873  0.58763   0.62522
#
#        hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 17056    0.67025         0.62230           0.71786       34.93068
# 17057    0.86682         0.90199           0.83769       35.11887
#
#        female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 17056         41.35474  0.18431  0.28188      0.04161     0.0094   0.13691
# 17057         33.74005  0.33470  0.49183      0.00000     0.0000   0.17831
#
#        pop_density  age_median  savings_after_rent  savings_after_mortgage
# 17056     0.001958   35.285022         29286.20199             19405.83075
# 17057     0.001833   33.501131         47409.11536             41387.23996

# %%
df_Maine.family_mean.mean()
# Out:
# 72455.80658626315

# %%
df_Maine.hc_mortgage_mean.mean()
# Out:
# 1416.2052472631578

# %%
df_Maine.savings_after_mortgage.mean()
# Out:
# 55461.34361910526

# %% [markdown]
# #### Highest Percent renter households (Lowest Percent owner households)

# %%
df_2_rent_family.groupby(['state'])[ 'pct_own'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# District of Columbia    0.429173
# California              0.550947
# Nevada                  0.553901
# New York                0.574317
# Hawaii                  0.585241
# Name: pct_own, dtype: float64

# %% [markdown]
# # Dennis to add Graph here

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median
# 0     0.000002   36.243001
# 1     0.000007   39.507468
# 3     0.000818   34.000000
# 4     0.003022   30.935701
# 5     0.002620   27.102687

# %% [markdown]
# #### Highest Debt

# %%
df_2_rent_family.groupby(['state'])[ 'debt'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    0.767057
# Maryland                0.742647
# California              0.724200
# Colorado                0.719448
# Rhode Island            0.710502
# Name: debt, dtype: float64

# %% [markdown]
# #### Lowest Debt

# %%
df_2_rent_family.groupby(['state'])[ 'debt'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico      0.376238
# West Virginia    0.477291
# North Dakota     0.478148
# Mississippi      0.507428
# Louisiana        0.512124
# Name: debt, dtype: float64

# %% [markdown]
# #### Highest Percentage of people with at least high school degree

# %%
df_2_rent_family.groupby(['state'])[ 'hs_degree'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# Wyoming          0.922823
# Montana          0.922446
# Hawaii           0.917553
# Minnesota        0.917060
# New Hampshire    0.915837
# Name: hs_degree, dtype: float64

# %% [markdown]
# #### Lowest Percentage of people with at least high school degree

# %%
df_2_rent_family.groupby(['state'])[ 'hs_degree'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico    0.722881
# Texas          0.805437
# Mississippi    0.810243
# California     0.811290
# Louisiana      0.822573
# Name: hs_degree, dtype: float64

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median
# 0     0.000002   36.243001
# 1     0.000007   39.507468
# 3     0.000818   34.000000
# 4     0.003022   30.935701
# 5     0.002620   27.102687

# %%
df_2_rent_family['bad_debt'] = (df_2_rent_family.second_mortgage + df_2_rent_family.home_equity)

# %%
df_2_rent_family.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median  savings_after_rent  savings_after_mortgage  \
# 0     0.000002   36.243001         97935.24581             87135.49721
# 1     0.000007   39.507468        120469.37537            118820.41505
# 3     0.000818   34.000000         67334.90414             51182.89214
# 4     0.003022   30.935701         64507.04066             58131.20810
# 5     0.002620   27.102687         68716.04329             60205.86121
#
#    bad_debt
# 0   0.04225
# 1   0.13485
# 3   0.04469
# 4   0.12597
# 5   0.08061

# %% [markdown]
# #### Highest Percentage of houses with bad debt ( second mortgage or home equity loan) sorted by State

# %%
df_2_rent_family.groupby(['state'])[ 'bad_debt'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    0.223185
# Maryland                0.196532
# Rhode Island            0.193324
# Connecticut             0.186915
# Colorado                0.185328
# Name: bad_debt, dtype: float64

# %%
df_2_rent_family.groupby(['state'])[ 'home_equity'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    0.159190
# Rhode Island            0.152381
# Maryland                0.151054
# Connecticut             0.146769
# Massachusetts           0.145506
# Name: home_equity, dtype: float64

# %%
df_2_rent_family.groupby(['state'])[ 'second_mortgage'].mean().sort_values(ascending=False).nlargest(5)
# Out:
# state
# District of Columbia    0.063995
# Colorado                0.055439
# Maryland                0.045478
# Utah                    0.043755
# California              0.043022
# Name: second_mortgage, dtype: float64

# %% [markdown]
# #### Lowest Percentage of houses with bad debt ( second mortgage or home equity loan) sorted by State

# %%
df_2_rent_family.groupby(['state'])[ 'bad_debt'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico    0.022885
# Texas          0.054210
# Arkansas       0.056137
# Mississippi    0.062523
# Oklahoma       0.064848
# Name: bad_debt, dtype: float64

# %%
df_2_rent_family.groupby(['state'])[ 'home_equity'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico    0.012698
# Texas          0.037156
# Arkansas       0.039670
# Oklahoma       0.043244
# Mississippi    0.046248
# Name: home_equity, dtype: float64

# %%
df_2_rent_family.groupby(['state'])[ 'second_mortgage'].mean().sort_values(ascending=False).nsmallest(5)
# Out:
# state
# Puerto Rico      0.010188
# West Virginia    0.014897
# Mississippi      0.016275
# Arkansas         0.016466
# Texas            0.017054
# Name: second_mortgage, dtype: float64

# %%
df_Maine = df_2_rent_family[df_2_rent_family.state=='Maine']
df_Maine.head(2)
# Out:
#        state    city  zip_code  rent_mean  family_mean  family_samples  \
# 17056  Maine  Auburn      4210  562.92812  36041.33943           226.0
# 17057  Maine  Auburn      4210  706.71217  55889.66140           540.0
#
#        hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 17056        1386.29239           0.0814      0.16279  0.87209   0.06303
# 17057        1208.53512           0.0000      0.06873  0.58763   0.62522
#
#        hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 17056    0.67025         0.62230           0.71786       34.93068
# 17057    0.86682         0.90199           0.83769       35.11887
#
#        female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 17056         41.35474  0.18431  0.28188      0.04161     0.0094   0.13691
# 17057         33.74005  0.33470  0.49183      0.00000     0.0000   0.17831
#
#        pop_density  age_median  savings_after_rent  savings_after_mortgage  \
# 17056     0.001958   35.285022         29286.20199             19405.83075
# 17057     0.001833   33.501131         47409.11536             41387.23996
#
#        bad_debt
# 17056   0.24419
# 17057   0.06873

# %%
df_Maine.bad_debt.mean()
# Out:
# 0.13755115789473685

# %%
df_2_rent_family.bad_debt.median()
# Out:
# 0.12320999999999999

# %%
df_2_rent_family.head(2)
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
#
#    pop_density  age_median  savings_after_rent  savings_after_mortgage  \
# 0     0.000002   36.243001         97935.24581             87135.49721
# 1     0.000007   39.507468        120469.37537            118820.41505
#
#    bad_debt
# 0   0.04225
# 1   0.13485

# %%
df_2_rent_family.female_age_mean.max()
# Out:
# 79.83739

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median
# 0     0.000002   36.243001
# 1     0.000007   39.507468
# 3     0.000818   34.000000
# 4     0.003022   30.935701
# 5     0.002620   27.102687

# %% [markdown]
# #### Let's try to train a decision tree to predict Bad Debt

# %%
dt = tree.DecisionTreeClassifier(max_depth=2)

# %%
type(dt)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
df.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median
# 0     0.000002   36.243001
# 1     0.000007   39.507468
# 3     0.000818   34.000000
# 4     0.003022   30.935701
# 5     0.002620   27.102687

# %%
df3=df_2_rent_family.copy()

# %%
df3.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median  savings_after_rent  savings_after_mortgage  \
# 0     0.000002   36.243001         97935.24581             87135.49721
# 1     0.000007   39.507468        120469.37537            118820.41505
# 3     0.000818   34.000000         67334.90414             51182.89214
# 4     0.003022   30.935701         64507.04066             58131.20810
# 5     0.002620   27.102687         68716.04329             60205.86121
#
#    bad_debt
# 0   0.04225
# 1   0.13485
# 3   0.04469
# 4   0.12597
# 5   0.08061

# %%
df3['state'].nunique()
# Out:
# 52

# %%
df3['city'].nunique()
# Out:
# 8144

# %%
df.columns
# Out:
# Index(['state', 'city', 'zip_code', 'rent_mean', 'family_mean',
#        'family_samples', 'hc_mortgage_mean', 'second_mortgage', 'home_equity',
#        'debt', 'debt_cdf', 'hs_degree', 'hs_degree_male', 'hs_degree_female',
#        'male_age_mean', 'female_age_mean', 'pct_own', 'married', 'married_snp',
#        'separated', 'divorced', 'pop_density', 'age_median'],
#       dtype='object')

# %% [markdown]
# #### Remove City, Zip_Code,rent_mean, hc_mortgage_mean, second_mortgage, home_equity,debt, debt_cdf,hs_degree_male, hs_degree_female:21409,

# %%
df3.head()
# Out:
#     state         city  zip_code   rent_mean   family_mean  family_samples  \
# 0  Alaska     Unalaska     99685  1366.24657  114330.20465           519.0
# 1  Alaska  Eagle River     99577  2347.69441  148641.70829           836.0
# 3  Alaska    Anchorage     99501   943.79086   78660.39446           390.0
# 4  Alaska    Anchorage     99504  1372.84472   80981.17730          1290.0
# 5  Alaska    Anchorage     99504  1351.27532   84931.34713          1297.0
#
#    hc_mortgage_mean  second_mortgage  home_equity     debt  debt_cdf  \
# 0        2266.22562          0.01408      0.02817  0.72770   0.30304
# 1        2485.10777          0.06078      0.07407  0.75689   0.23925
# 3        2289.79186          0.00000      0.04469  0.78212   0.18899
# 4        1904.16410          0.04083      0.08514  0.67246   0.43422
# 5        2060.45716          0.02897      0.05164  0.74685   0.26073
#
#    hs_degree  hs_degree_male  hs_degree_female  male_age_mean  \
# 0    0.82841         0.82784           0.82940       38.45838
# 1    0.94090         0.97253           0.91503       37.26216
# 3    0.89274         0.94301           0.84871       35.81912
# 4    0.95351         0.96060           0.94669       34.13110
# 5    0.87941         0.90837           0.84932       29.23608
#
#    female_age_mean  pct_own  married  married_snp  separated  divorced  \
# 0         32.78177  0.25053  0.47388      0.30134    0.03443   0.09802
# 1         38.97956  0.94989  0.52381      0.01777    0.00782   0.13575
# 3         37.00750  0.20247  0.44428      0.05933    0.00000   0.21563
# 4         34.96611  0.56936  0.51034      0.08315    0.06731   0.08711
# 5         33.63770  0.45011  0.39429      0.04615    0.02418   0.10242
#
#    pop_density  age_median  savings_after_rent  savings_after_mortgage  \
# 0     0.000002   36.243001         97935.24581             87135.49721
# 1     0.000007   39.507468        120469.37537            118820.41505
# 3     0.000818   34.000000         67334.90414             51182.89214
# 4     0.003022   30.935701         64507.04066             58131.20810
# 5     0.002620   27.102687         68716.04329             60205.86121
#
#    bad_debt
# 0   0.04225
# 1   0.13485
# 3   0.04469
# 4   0.12597
# 5   0.08061

# %%
df3.drop(['city', 'zip_code', 'rent_mean','hc_mortgage_mean',\
         'second_mortgage','home_equity','debt','debt_cdf','hs_degree_male','hs_degree_female','female_age_mean',\
         'savings_after_rent'], axis=1, inplace=True)

# %%
df3.head()
# Out:
#     state   family_mean  family_samples  hs_degree  male_age_mean  pct_own  \
# 0  Alaska  114330.20465           519.0    0.82841       38.45838  0.25053
# 1  Alaska  148641.70829           836.0    0.94090       37.26216  0.94989
# 3  Alaska   78660.39446           390.0    0.89274       35.81912  0.20247
# 4  Alaska   80981.17730          1290.0    0.95351       34.13110  0.56936
# 5  Alaska   84931.34713          1297.0    0.87941       29.23608  0.45011
#
#    married  married_snp  separated  divorced  pop_density  age_median  \
# 0  0.47388      0.30134    0.03443   0.09802     0.000002   36.243001
# 1  0.52381      0.01777    0.00782   0.13575     0.000007   39.507468
# 3  0.44428      0.05933    0.00000   0.21563     0.000818   34.000000
# 4  0.51034      0.08315    0.06731   0.08711     0.003022   30.935701
# 5  0.39429      0.04615    0.02418   0.10242     0.002620   27.102687
#
#    savings_after_mortgage  bad_debt
# 0             87135.49721   0.04225
# 1            118820.41505   0.13485
# 3             51182.89214   0.04469
# 4             58131.20810   0.12597
# 5             60205.86121   0.08061

# %%
df3.corr()
# Out:
#                         family_mean  family_samples  hs_degree  male_age_mean  \
# family_mean                1.000000        0.213010   0.646265       0.260290
# family_samples             0.213010        1.000000   0.160737      -0.031977
# hs_degree                  0.646265        0.160737   1.000000       0.332217
# male_age_mean              0.260290       -0.031977   0.332217       1.000000
# pct_own                    0.454374        0.284076   0.408167       0.461094
# married                    0.496907        0.400074   0.383788       0.406999
# married_snp               -0.330095       -0.149700  -0.458866      -0.166698
# separated                 -0.333302       -0.138685  -0.332956      -0.112301
# divorced                  -0.375001       -0.172291  -0.088909       0.186499
# pop_density               -0.022534       -0.082553  -0.191204      -0.163356
# age_median                 0.298403        0.023998   0.353872       0.932161
# savings_after_mortgage     0.982561        0.223246   0.679943       0.285408
# bad_debt                   0.375901        0.125802   0.294631      -0.042520
#
#                          pct_own   married  married_snp  separated  divorced  \
# family_mean             0.454374  0.496907    -0.330095  -0.333302 -0.375001
# family_samples          0.284076  0.400074    -0.149700  -0.138685 -0.172291
# hs_degree               0.408167  0.383788    -0.458866  -0.332956 -0.088909
# male_age_mean           0.461094  0.406999    -0.166698  -0.112301  0.186499
# pct_own                 1.000000  0.698335    -0.397889  -0.298946 -0.116875
# married                 0.698335  1.000000    -0.249751  -0.231122 -0.294890
# married_snp            -0.397889 -0.249751     1.000000   0.685813  0.050874
# separated              -0.298946 -0.231122     0.685813   1.000000  0.128152
# divorced               -0.116875 -0.294890     0.050874   0.128152  1.000000
# pop_density            -0.428333 -0.250206     0.212864   0.092094 -0.160546
# age_median              0.545910  0.492777    -0.199225  -0.128585  0.145365
# savings_after_mortgage  0.527481  0.530170    -0.372117  -0.347947 -0.331023
# bad_debt                0.073521  0.136180    -0.118258  -0.125500 -0.187271
#
#                         pop_density  age_median  savings_after_mortgage  \
# family_mean               -0.022534    0.298403                0.982561
# family_samples            -0.082553    0.023998                0.223246
# hs_degree                 -0.191204    0.353872                0.679943
# male_age_mean             -0.163356    0.932161                0.285408
# pct_own                   -0.428333    0.545910                0.527481
# married                   -0.250206    0.492777                0.530170
# married_snp                0.212864   -0.199225               -0.372117
# separated                  0.092094   -0.128585               -0.347947
# divorced                  -0.160546    0.145365               -0.331023
# pop_density                1.000000   -0.199316               -0.109895
# age_median                -0.199316    1.000000                0.325473
# savings_after_mortgage    -0.109895    0.325473                1.000000
# bad_debt                   0.001666   -0.005846                0.334568
#
#                         bad_debt
# family_mean             0.375901
# family_samples          0.125802
# hs_degree               0.294631
# male_age_mean          -0.042520
# pct_own                 0.073521
# married                 0.136180
# married_snp            -0.118258
# separated              -0.125500
# divorced               -0.187271
# pop_density             0.001666
# age_median             -0.005846
# savings_after_mortgage  0.334568
# bad_debt                1.000000

# %% [markdown]
# #### Dropping family_mean due to high corelation with savings_after_mortgage

# %%
df3.drop('family_mean', axis=1,inplace=True)

# %%
df3['Savings_atleast_50K'] = df3['savings_after_mortgage'].apply(lambda x: 1 if x >= 50000 else 0 )

# %%
df3.head()
# Out:
#     state  family_samples  hs_degree  male_age_mean  pct_own  married  \
# 0  Alaska           519.0    0.82841       38.45838  0.25053  0.47388
# 1  Alaska           836.0    0.94090       37.26216  0.94989  0.52381
# 3  Alaska           390.0    0.89274       35.81912  0.20247  0.44428
# 4  Alaska          1290.0    0.95351       34.13110  0.56936  0.51034
# 5  Alaska          1297.0    0.87941       29.23608  0.45011  0.39429
#
#    married_snp  separated  divorced  pop_density  age_median  \
# 0      0.30134    0.03443   0.09802     0.000002   36.243001
# 1      0.01777    0.00782   0.13575     0.000007   39.507468
# 3      0.05933    0.00000   0.21563     0.000818   34.000000
# 4      0.08315    0.06731   0.08711     0.003022   30.935701
# 5      0.04615    0.02418   0.10242     0.002620   27.102687
#
#    savings_after_mortgage  bad_debt  Savings_atleast_50K
# 0             87135.49721   0.04225                    1
# 1            118820.41505   0.13485                    1
# 3             51182.89214   0.04469                    1
# 4             58131.20810   0.12597                    1
# 5             60205.86121   0.08061                    1

# %%
df3.drop('savings_after_mortgage', axis=1,inplace=True)

# %%
df3.drop('pct_own', axis=1,inplace=True)

# %%
df3.head()
# Out:
#     state  family_samples  hs_degree  male_age_mean  married  married_snp  \
# 0  Alaska           519.0    0.82841       38.45838  0.47388      0.30134
# 1  Alaska           836.0    0.94090       37.26216  0.52381      0.01777
# 3  Alaska           390.0    0.89274       35.81912  0.44428      0.05933
# 4  Alaska          1290.0    0.95351       34.13110  0.51034      0.08315
# 5  Alaska          1297.0    0.87941       29.23608  0.39429      0.04615
#
#    separated  divorced  pop_density  age_median  bad_debt  Savings_atleast_50K
# 0    0.03443   0.09802     0.000002   36.243001   0.04225                    1
# 1    0.00782   0.13575     0.000007   39.507468   0.13485                    1
# 3    0.00000   0.21563     0.000818   34.000000   0.04469                    1
# 4    0.06731   0.08711     0.003022   30.935701   0.12597                    1
# 5    0.02418   0.10242     0.002620   27.102687   0.08061                    1

# %%
df3 = pd.get_dummies(df3, columns=['state'], dummy_na=True)

# %%
df3.head(1)
# Out:
#    family_samples  hs_degree  male_age_mean  married  married_snp  separated  \
# 0           519.0    0.82841       38.45838  0.47388      0.30134    0.03443
#
#    divorced  pop_density  age_median  bad_debt  Savings_atleast_50K  \
# 0   0.09802     0.000002   36.243001   0.04225                    1
#
#    state_Alabama  state_Alaska  state_Arizona  state_Arkansas  \
# 0              0             1              0               0
#
#    state_California  state_Colorado  state_Connecticut  state_Delaware  \
# 0                 0               0                  0               0
#
#    state_District of Columbia  state_Florida  state_Georgia  state_Hawaii  \
# 0                           0              0              0             0
#
#    state_Idaho  state_Illinois  state_Indiana  state_Iowa  state_Kansas  \
# 0            0               0              0           0             0
#
#    state_Kentucky  state_Louisiana  state_Maine  state_Maryland  \
# 0               0                0            0               0
#
#    state_Massachusetts  state_Michigan  state_Minnesota  state_Mississippi  \
# 0                    0               0                0                  0
#
#    state_Missouri  state_Montana  state_Nebraska  state_Nevada  \
# 0               0              0               0             0
#
#    state_New Hampshire  state_New Jersey  state_New Mexico  state_New York  \
# 0                    0                 0                 0               0
#
#    state_North Carolina  state_North Dakota  state_Ohio  state_Oklahoma  \
# 0                     0                   0           0               0
#
#    state_Oregon  state_Pennsylvania  state_Puerto Rico  state_Rhode Island  \
# 0             0                   0                  0                   0
#
#    state_South Carolina  state_South Dakota  state_Tennessee  state_Texas  \
# 0                     0                   0                0            0
#
#    state_Utah  state_Vermont  state_Virginia  state_Washington  \
# 0           0              0               0                 0
#
#    state_West Virginia  state_Wisconsin  state_Wyoming  state_nan
# 0                    0                0              0          0

# %% [markdown]
# ## Train the decision tree

# %%
Y = df3.Savings_atleast_50K

# %%
X = df3.drop('Savings_atleast_50K', axis=1)

# %%
dt.fit(X,Y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# This code will visualize a decision tree dt, trained with the attributes in X and the class labels in Y
import os
os.environ["PATH"] += os.pathsep + r'C:\Users\indra.chatterjee\Anaconda3\Library\bin\graphviz'
dt_feature_names = list(X.columns)
dt_target_names = [str(s) for s in Y.unique()]
tree.export_graphviz(dt, out_file='tree.dot', 
    feature_names=dt_feature_names, class_names=dt_target_names,
    filled=True)  
graph = pydotplus.graph_from_dot_file('tree.dot')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-90-f0cd7ab698b9> in <module>
#       8     filled=True)
#       9 graph = pydotplus.graph_from_dot_file('tree.dot')
# ---> 10 Image(graph.create_png())
#
# c:\users\tony\desktop\github\dataquest-modules\venv\lib\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# c:\users\tony\desktop\github\dataquest-modules\venv\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found
