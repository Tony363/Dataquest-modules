# %%
import pandas as pd 
import numpy as np

path = r'/home/tony/Downloads/MarkoPractice1.csv'

df = pd.read_csv(path)
df2 = pd.read_csv(r'/home/tony/Downloads/MarkoPractice2.csv')

# %%
df3 = pd.concat([df,df2])

# %%
df3
# Out:
#               driver  vehicle_number   best    avg      1      2      3  \
# 0       Clint Bowyer              14  178.4  176.2  174.5  175.8  176.1
# 1      Aric Almirola              10  178.7  175.8  173.1  176.3  176.8
# 2      Chase Elliott               9  177.2  175.8  173.5  175.9  176.5
# 3        Alex Bowman              88  177.6  175.7  172.4    175  176.2
# 4         Kurt Busch               1  177.2  175.6  172.8  175.4    176
# ..               ...             ...    ...    ...    ...    ...    ...
# 33        J.J. Yeley              52  172.1  171.4  168.7    169  171.2
# 34     Reed Sorenson              77  171.5  170.6  169.5  171.5    5.8
# 35  Garrett Smithley              51  167.3  167.3  164.8  167.3    9.1
# 36         Joey Gase              53  168.9  168.9  160.3  165.2  163.5
# 37        Timmy Hill              66  164.1  164.1  159.2      X  162.5
#
#         4      5      6  ...   56   57   58   59   60   61   62   63   64   65
# ...

# %%
df.head()

# %%
type(df.iloc[0,29])

# %%
df.describe()

# %%
df.dtypes

# %%
df.replace('X',np.nan,inplace=True)

# %%
df = df.sort_values(['vehicle_number']).set_index(['vehicle_number'])

# %%
df

# %%
df.best.mean() - df.avg.mean()

# %%
df.best.mean()

# %%
df.avg.mean()

# %%
df.columns

# %%
df.drop(['driver','best'],axis=1).mean(axis=1)

# %%
df.drop(['driver','best'],axis=1).mean(axis=1)

# %%
 df.avg

# %%
df.best.unique()

# %%
df.avg.unique()

# %%
df.best.nunique()

# %%
df.avg.nunique()
