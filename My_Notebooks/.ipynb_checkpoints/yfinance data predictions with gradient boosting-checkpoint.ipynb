# %% [markdown]
# ## stock ADVC from New York stock exchange

# %%
import yfinance as yf

advc = yf.Ticker('AAPL')

advc.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408-996-1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'previousClose': 316.57,
#  'regularMarketOpen': 318.58,
#  'twoHundredDayAverage': 241.24445,
#  'trailingAnnualDividendYield': 0.009476577,
#  'payoutRatio': 0.2523,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 319.99,
#  'navPrice': None,
#  'averageDailyVolume10Day': 31779683,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 316.57,
#  'fiftyDayAverage': 289.5006,
#  'trailingAnnualDividendRate': 3,
#  'open': 318.58,
#  'averageVolume10days': 31779683,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 3.08,
#  'exDividendDate': 1572998400,
#  'beta': 1.244671,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 317.31,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 26.719933,
#  'regularMarketVolume': 25458115,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1392806461440,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 27018948,
#  'priceToSalesTrailing12Months': 5.3533654,
#  'dayLow': 317.31,
#  'ask': 317.65,
#  'ytdReturn': None,
#  'askSize': 1000,
#  'volume': 25458115,
#  'fiftyTwoWeekHigh': 319.99,
#  'forwardPE': 20.998018,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.62,
#  'fiftyTwoWeekLow': 151.7,
#  'bid': 317.56,
#  'tradeable': True,
#  'dividendYield': 0.0097,
#  'bidSize': 800,
#  'dayHigh': 319.99,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 5.435,
#  'beta3Year': None,
#  'profitMargins': 0.21238,
#  'enterpriseToEbitda': 18.49,
#  '52WeekChange': 1.0731502,
#  'morningStarRiskRating': None,
#  'forwardEps': 15.13,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 4384030208,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 20.365,
#  'sharesShort': 45514898,
#  'sharesPercentSharesOut': 0.010199999,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1569628800,
#  'heldPercentInstitutions': 0.62404996,
#  'netIncomeToCommon': 55255998464,
#  'trailingEps': 11.89,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.25676584,
#  'priceToBook': 15.600295,
#  'heldPercentInsiders': 0.00065,
#  'nextFiscalYearEnd': 1632787200,
#  'mostRecentQuarter': 1569628800,
#  'shortRatio': 1.6,
#  'sharesShortPreviousMonthDate': 1574985600,
#  'floatShares': 4185911091,
#  'enterpriseValue': 1414094389248,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1402272000,
#  'lastSplitFactor': '7:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.031,
#  'dateShortInterest': 1577750400,
#  'pegRatio': 2.29,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0095999995,
#  'sharesShortPriorMonth': 63489595,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 318.58,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
hist = advc.history(period='max')

# %%
type(hist)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
hist = pd.DataFrame(hist)

# %%
hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %% [markdown]
# ## history of stock values

# %%
hist['2003':'2010']
# Out:
#              Open   High    Low  Close    Volume  Dividends  Stock Splits
# Date
# 2003-01-02   0.89   0.93   0.89   0.92  45357200        0.0           0.0
# 2003-01-03   0.92   0.93   0.91   0.93  36863400        0.0           0.0
# 2003-01-06   0.93   0.96   0.92   0.93  97633200        0.0           0.0
# 2003-01-07   0.92   0.93   0.90   0.92  85586200        0.0           0.0
# 2003-01-08   0.91   0.91   0.90   0.90  57411200        0.0           0.0
# ...           ...    ...    ...    ...       ...        ...           ...
# 2010-12-27  40.13  40.45  39.96  40.36  62454000        0.0           0.0
# 2010-12-28  40.51  40.60  40.40  40.46  43981000        0.0           0.0
# 2010-12-29  40.55  40.58  40.41  40.43  40784800        0.0           0.0
# 2010-12-30  40.46  40.46  40.16  40.23  39373600        0.0           0.0
# 2010-12-31  40.14  40.21  39.94  40.09  48377000        0.0           0.0
#
# [2015 rows x 7 columns]

# %% [markdown]
# ## Assign features of high/low percentage, percentage change, Close and Volume

# %%
hist['HL_PCT'] = (hist['High'] - hist['Close'])/ hist['Close'] * 100

# %%
hist['PCT_change'] = (hist['Close'] - hist['Open'])/ hist['Open'] * 100

# %%
linear_reg = hist[['Close','HL_PCT',"PCT_change",'Volume']]

# %%
linear_reg.tail()
# Out:
#              Close    HL_PCT  PCT_change    Volume
# Date
# 2020-01-15  311.34  1.336160   -0.163540  30480900
# 2020-01-16  315.24  0.145921    0.526165  27207300
# 2020-01-17  318.73  0.003137    0.777816  34454100
# 2020-01-21  316.57  0.773920   -0.195466  27710800
# 2020-01-22  317.70  0.720806   -0.276226  25392800

# %% [markdown]
# # Decide on Label

# %%
forecast_col = 'Close'

# %%
linear_reg.fillna(-9999,inplace=True)
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/pandas/core/frame.py:4259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %% [markdown]
# filter and replace NaN values

# %%
import math
forecast_out = int(math.ceil(0.1*len(linear_reg)))

# %% [markdown]
# Decide on forcast futures by a portion of the maximum ceiling of row entries in dataframe

# %%
forecast_out
# Out:
# 986

# %% [markdown]
# forecasting out by 409 days

# %%
linear_reg['label'] = linear_reg[forecast_col].shift(-forecast_out)
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# shifting dataframe to unknown values above dataframe

# %%
linear_reg.head()
# Out:
#             Close  HL_PCT  PCT_change     Volume  label
# Date
# 1980-12-12   0.41     0.0         0.0  117258400   0.37
# 1980-12-15   0.39     0.0         0.0   43971200   0.37
# 1980-12-16   0.36     0.0         0.0   26432000   0.35
# 1980-12-17   0.37     0.0         0.0   21610400   0.33
# 1980-12-18   0.38     0.0         0.0   18362400   0.34

# %% [markdown]
# ## Via regression analysis

# %%
import numpy as np
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,cross_validate


X = np.array(linear_reg.drop(['label'],axis=1))
X = preprocessing.scale(X)
X = X[:-forecast_out]
X_lately = X[-forecast_out:]

linear_reg.dropna(inplace=True)
y = np.array(linear_reg['label'])


# X = X[:-forecast_out + 1]
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %% [markdown]
# define features and labels, X,y

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
#clf = svm.SVR()#kernel='poly'
clf = LinearRegression(n_jobs=-1)

# %% [markdown]
# using linear regression

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %% [markdown]
# training/fitting train data

# %%
accuracy_LR = clf.score(X_test,y_test)

# %%
accuracy_LR
# Out:
# 0.9049372880117694

# %% [markdown]
# ## Via xgboost XGBRegressor

# %%
import xgboost as xgb 
from xgboost.sklearn import XGBClassifier, XGBRegressor, XGBRFRegressor

classifier = xgb.sklearn.XGBRegressor()

# %%
classifier.fit(X_train,y_train)
# Out:
# [19:09:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predictions_xgb = classifier.predict(X_test)

# %%
accuracy_xgb = classifier.score(X_test,y_test)
accuracy_xgb
# Out:
# 0.9596129678613091

# %%
# import os
# os.environ["PATH"] += os.pathsep + '~/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/graphviz'

# %%
import matplotlib.pyplot as plt
xgb.plot_tree(classifier,num_trees=0)
plt.rcParams['figure.figsize'] = [100,5]
plt.show()

# %% [markdown]
# ## Via XGBoost random forest prediction

# %%
RF = xgb.sklearn.XGBRFRegressor()

# %%
RF.fit(X_train,y_train)
# Out:
# [19:09:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRFRegressor(base_score=0.5, colsample_bylevel=1, colsample_bynode=0.8,
#                colsample_bytree=1, gamma=0, learning_rate=1, max_delta_step=0,
#                max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#                n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                silent=None, subsample=0.8, verbosity=1)

# %%
accuracy_RF = RF.score(X_test,y_test)

# %%
accuracy_RF
# Out:
# 0.94572235230784

# %% [markdown]
# ## XGBoost Dmatrix plot importance

# %%
def prepare_X_y(data):
    X = data
   
    ind = list(data.columns).index('Close')
    print(ind)

    y = []
    for i in range(X.shape[0]-1):
        if (X.iloc[i+1,ind] - X.iloc[i,ind])>0:
            y.append(1)
        else:
            y.append(0)
    y = np.array(y)
    print(len(y))
    X = X[:-1].values
    print(len(X))
    return X,y

# %%
# X,y = prepare_X_y(linear_reg)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
from sklearn.datasets import dump_svmlight_file

dump_svmlight_file(X_train,y_train,'dtrain.svm',zero_based=True)
dump_svmlight_file(X_test, y_test, 'dtest.svm', zero_based=True)
dtrain_svm = xgb.DMatrix('dtrain.svm')
dtest_svm = xgb.DMatrix('dtest.svm')
# Out:
# [19:09:48] 7099x4 matrix with 28396 entries loaded from dtrain.svm
# [19:09:48] 1775x4 matrix with 7100 entries loaded from dtest.svm

# %%
# params = {
#     'max_depth': 2,
#     'eta': 2,
#     'verbosity': 1,
#     'objective':'reg:squarederror',

# }
params = {'max_depth': 2,
#               'eta': 0.1,
#               'lambda': 1,
#               'gamma': 0,
#               'min_child_weight': 3,
             'objective':'reg:squarederror',
}

# %%
bst = xgb.train(params=params,dtrain=dtrain,num_boost_round=10)

# %%
bst.dump_model('dump.raw.txt')

# %%
import numpy as np 
from sklearn.metrics import precision_score, recall_score, accuracy_score

pred = bst.predict(dtest)
best_preds = np.asarray([np.argmax(line) for line in pred])

# %%
pred.shape
# Out:
# (1775,)

# %%
# print(f"Precision : {precision_score(y_test,best_preds,average='samples')}")
# print(f"Precision : {recall_score(y_test,best_preds,average='macro')}")
# print(f"Precision : {accuracy_score(y_test,best_preds,average='macro')}")

# %%
xgb.plot_importance(bst)

# %%
xgb.plot_tree(bst,num_trees=0)
plt.rcParams['figure.figsize'] = [10,5]
plt.show()

# %%
xgb.to_graphviz(bst,num_trees=2)

# %% [markdown]
# ## Predict forcast(X_lately) with trained data using different algorithms

# %%
forecast_set = clf.predict(X_lately)

# %% [markdown]
# for regression analysis

# %%
forecast_xgb = classifier.predict(X_lately)

# %% [markdown]
# for xgboost regressor analysis

# %%
RF_forecast = RF.predict(X_lately)

# %% [markdown]
# for best_forcast

# %%
X_lately.shape
# Out:
# (986, 4)

# %%
y_test.shape
# Out:
# (1775,)

# %%
dtrain = xgb.DMatrix(X_lately, label=y_test)
dtest = xgb.DMatrix(X_lately, label=y_test)

# %%
bst_forcast = bst.predict(dtest)

# %% [markdown]
# ## Plotting stock Forecast for next year from linear regression analysis

# %%
import matplotlib.pyplot as plt
import datetime
from matplotlib import style

style.use('ggplot')

# %%
linear_reg['Forecast'] = np.nan
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
last_date = linear_reg.iloc[-1].name

# %%
last_unix = last_date.timestamp()

# %%
one_day = 86400

# %%
next_unix = last_unix + one_day

# %%
for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    linear_reg.loc[next_date] = [np.nan for _ in range(len(linear_reg.columns)-1)] + [i]
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
linear_reg['2019-01-01':'2019-02-01']
# Out:
# Empty DataFrame
# Columns: [Close, HL_PCT, PCT_change, Volume, label, Forecast]
# Index: []

# %%
linear_reg['Close'].plot()
linear_reg['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Plotting data from gradient boosted forcast

# %%
linear_reg['2019-01-01':'2019-02-01']
# Out:
# Empty DataFrame
# Columns: [Close, HL_PCT, PCT_change, Volume, label, Forecast]
# Index: []

# %%
for i in forecast_xgb:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    linear_reg.loc[next_date] = [np.nan for _ in range(len(linear_reg.columns)-1)] + [i]
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
linear_reg['Close'].plot()
linear_reg['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Plotting forecast from random forest gradient boosting

# %%
for i in RF_forecast:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    linear_reg.loc[next_date] = [np.nan for _ in range(len(linear_reg.columns)-1)] + [i]
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
linear_reg['Close'].plot()
linear_reg['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
linear_reg['2018-05-15':'2018-05-18']
# Out:
#                      Close  HL_PCT  PCT_change  Volume  label    Forecast
# Date
# 2018-05-15 08:00:00    NaN     NaN         NaN     NaN    NaN  229.941499
# 2018-05-16 08:00:00    NaN     NaN         NaN     NaN    NaN  230.741586
# 2018-05-17 08:00:00    NaN     NaN         NaN     NaN    NaN  230.465881
# 2018-05-18 08:00:00    NaN     NaN         NaN     NaN    NaN  231.208058

# %% [markdown]
# ## Forcast with XGB Dmatrix bst_forcast

# %%
for i in bst_forcast:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    linear_reg.loc[next_date] = [np.nan for _ in range(len(linear_reg.columns)-1)] + [i]
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
linear_reg['Close'].plot()
linear_reg['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Don't know why there is a sudden drop in forecast values

# %% [markdown]
# ## Applying custom functions for accuracy predictions

# %%
import numpy as np
import pandas as pd

def prepare_X_y(data):
    X = data
   
    ind = list(data.columns).index('Close')
    print(ind)

    y = []
    for i in range(X.shape[0]-1):
        if (X.iloc[i+1,ind] - X.iloc[i,ind])>0:
            y.append(1)
        else:
            y.append(0)
    y = np.array(y)
    print(len(y))
    X = X[:-1].values
    print(len(X))
    return X,y

# %%
X,y = prepare_X_y(hist)
# Out:
# 3
# 9859
# 9859

# %%
X.shape
# Out:
# (9859, 9)

# %%
y.shape
# Out:
# (9859,)

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

def split_train_test(X,y):
    split_ratio=0.9
    train_size = int(round(split_ratio * X.shape[0]))
    X_train = X[:train_size]
    y_train = y[:train_size]
    X_test = X[train_size:]
    y_test = y[train_size:]

    print(X_train.shape, y_train.shape)
    print(X_test.shape, y_test.shape)
    return X_train, X_test, y_train, y_test

def train_model(X_train, y_train):
#     model = xgb.XGBClassifier()
    model = xgb.XGBRegressor(objective='reg:squarederror')
    model.fit(X_train, y_train)
    return model
  

def predict(model):
    y_pred = model.predict(X_test)
    y_pred = [round(value) for value in y_pred]
    accuracy = accuracy_score(y_test, y_pred)
    return "Accuracy: %.2f%%" % (accuracy * 100.0)
# view rawtraining.py hosted with ❤ by GitHub

# %%
X_train,X_test,y_train,y_test = split_train_test(X,y)
# Out:
# (8873, 9) (8873,)
# (986, 9) (986,)

# %%
model = train_model(X_train,y_train)

# %%
prediction = predict(model)

# %%
print(prediction)
# Out:
# Accuracy: 46.35%

# %% [markdown]
# ## Plot feature importance from custom function

# %%
def plot_feature_imp(data, model):
    imp_score = pd.DataFrame(model.feature_importances_, columns=['Importance Score'])
    features = pd.DataFrame(data.columns, columns=['Features'])
    feature_imp = pd.concat([features,imp_score], axis=1)
    feature_imp = feature_imp.sort_index(by='Importance Score', ascending=False)
    sns.barplot(x=feature_imp['Importance Score'], y=feature_imp['Features'])
    plt.show()

# %%
plot_feature_imp(linear_reg,model)
# Out:
# /home/tony/Desktop/github_repos/Dataquest-modules/venv/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """

# %% [markdown]
# ## Adding key financial Indicators and Indices

# %%
# Moving Averages (SMA & EWMA)


# Simple Moving Average 
def SMA(data, days): 
    sma = pd.Series(data['Close'].rolling(window=days).mean())
    name = 'SMA_' + str(days) + '_days'
    data[name] = sma
    return data

# Exponentially-weighted Moving Average 
def EWMA(data, days):
    ema = pd.Series(data['Close'].ewm(span = days , min_periods = days -1).mean())
    name = 'EWMA_' + str(days) + '_days'
    data[name] = ema
    return data

days_list = [1,2,4,6]
for days in days_list:
    SMA_ = SMA(hist,days)
    EWMA_ = EWMA(hist,days)

# %%
hist.head()
# Out:
#             Open  High   Low  Close     Volume  Dividends  Stock Splits  \
# Date
# 1980-12-12  0.41  0.41  0.41   0.41  117258400        0.0           0.0
# 1980-12-15  0.39  0.39  0.39   0.39   43971200        0.0           0.0
# 1980-12-16  0.36  0.36  0.36   0.36   26432000        0.0           0.0
# 1980-12-17  0.37  0.37  0.37   0.37   21610400        0.0           0.0
# 1980-12-18  0.38  0.38  0.38   0.38   18362400        0.0           0.0
#
#             HL_PCT  PCT_change  SMA_1_days  EWMA_1_days  SMA_2_days  \
# Date
# 1980-12-12     0.0         0.0        0.41         0.41         NaN
# 1980-12-15     0.0         0.0        0.39         0.39       0.400
# 1980-12-16     0.0         0.0        0.36         0.36       0.375
# 1980-12-17     0.0         0.0        0.37         0.37       0.365
# 1980-12-18     0.0         0.0        0.38         0.38       0.375
#
#             EWMA_2_days  SMA_4_days  EWMA_4_days  SMA_6_days  EWMA_6_days
# Date
# 1980-12-12     0.410000         NaN          NaN         NaN          NaN
# 1980-12-15     0.395000         NaN          NaN         NaN          NaN
# 1980-12-16     0.370769         NaN     0.378367         NaN          NaN
# 1980-12-17     0.370250      0.3825     0.374522         NaN          NaN
# 1980-12-18     0.376777      0.3750     0.376898         NaN     0.377932

# %%
#Bollinger Bands (UpperBB & LowerBB)
def bbands(data, window=days):
    MA = data.Close.rolling(window=days).mean()
    SD = data.Close.rolling(window=days).std()
    data['UpperBB'] = MA + (2 * SD) 
    data['LowerBB'] = MA - (2 * SD)
    return data
days = 12
bbands_ = bbands(hist, days)

# %%
hist.tail(100)
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits  \
# Date
# 2019-08-29  207.88  208.69  206.04  208.38  20990500        0.0           0.0
# 2019-08-30  209.53  209.82  206.58  208.12  21143400        0.0           0.0
# 2019-09-03  205.81  206.36  203.61  205.08  20023000        0.0           0.0
# 2019-09-04  207.77  208.85  206.70  208.56  19188100        0.0           0.0
# 2019-09-05  211.37  213.33  210.88  212.64  23913700        0.0           0.0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-01-15  311.85  315.50  309.55  311.34  30480900        0.0           0.0
# 2020-01-16  313.59  315.70  312.09  315.24  27207300        0.0           0.0
# 2020-01-17  316.27  318.74  315.00  318.73  34454100        0.0           0.0
# 2020-01-21  317.19  319.02  316.00  316.57  27710800        0.0           0.0
# 2020-01-22  318.58  319.99  317.31  317.70  25392800        0.0           0.0
#
#               HL_PCT  PCT_change  SMA_1_days  EWMA_1_days  SMA_2_days  \
# Date
# 2019-08-29  0.148767    0.240523      208.38       208.38     206.645
# 2019-08-30  0.816836   -0.672935      208.12       208.12     208.250
# 2019-09-03  0.624147   -0.354696      205.08       205.08     206.600
# 2019-09-04  0.139049    0.380228      208.56       208.56     206.820
# 2019-09-05  0.324492    0.600842      212.64       212.64     210.600
# ...              ...         ...         ...          ...         ...
# 2020-01-15  1.336160   -0.163540      311.34       311.34     312.010
# 2020-01-16  0.145921    0.526165      315.24       315.24     313.290
# 2020-01-17  0.003137    0.777816      318.73       318.73     316.985
# 2020-01-21  0.773920   -0.195466      316.57       316.57     317.650
# 2020-01-22  0.720806   -0.276226      317.70       317.70     317.135
#
#             EWMA_2_days  SMA_4_days  EWMA_4_days  SMA_6_days  EWMA_6_days  \
# Date
# 2019-08-29   207.149973    205.6775   206.456613  206.093333   206.363355
# 2019-08-30   207.796658    206.2400   207.121968  205.476667   206.865253
# 2019-09-03   205.985553    206.6225   206.305181  205.985000   206.355181
# 2019-09-04   207.701851    207.5350   207.207108  206.433333   206.985129
# 2019-09-05   210.993950    208.6000   209.380265  207.948333   208.600807
# ...                 ...         ...          ...         ...          ...
# 2020-01-15   311.975240    312.8275   311.408611  310.688333   309.769296
# 2020-01-16   314.151747    314.0550   312.941167  312.696667   311.332355
# 2020-01-17   317.203916    314.4975   315.256700  314.213333   313.445968
# 2020-01-21   316.781305    315.4700   315.782020  315.253333   314.338548
# 2020-01-22   317.393768    317.0600   316.549212  315.376667   315.298963
#
#                UpperBB     LowerBB
# Date
# 2019-08-29  214.119377  198.742290
# 2019-08-30  214.166059  199.692274
# 2019-09-03  213.657387  200.857613
# 2019-09-04  213.857966  201.103701
# 2019-09-05  214.671477  200.776856
# ...                ...         ...
# 2020-01-15  320.148234  287.396766
# 2020-01-16  321.380674  290.117659
# 2020-01-17  323.114115  292.564219
# 2020-01-21  324.444529  293.937138
# 2020-01-22  324.889168  296.870832
#
# [100 rows x 19 columns]

# %%
# Force Index (ForceIndex)
def ForceIndex(data, days): 
    FI = pd.Series(data['Close'].diff(periods=days) * data['Volume'])#, name = 'ForceIndex') 
    data['ForceIndex'] = FI 
    return data
days = 1
ForceIndex_ = ForceIndex(hist,days)

# %%
hist.head(1000)
# Out:
#             Open  High   Low  Close     Volume  Dividends  Stock Splits  \
# Date
# 1980-12-12  0.41  0.41  0.41   0.41  117258400        0.0           0.0
# 1980-12-15  0.39  0.39  0.39   0.39   43971200        0.0           0.0
# 1980-12-16  0.36  0.36  0.36   0.36   26432000        0.0           0.0
# 1980-12-17  0.37  0.37  0.37   0.37   21610400        0.0           0.0
# 1980-12-18  0.38  0.38  0.38   0.38   18362400        0.0           0.0
# ...          ...   ...   ...    ...        ...        ...           ...
# 1984-11-19  0.33  0.33  0.31   0.31   58245600        0.0           0.0
# 1984-11-20  0.32  0.32  0.32   0.32   65811200        0.0           0.0
# 1984-11-21  0.33  0.33  0.33   0.33   44682400        0.0           0.0
# 1984-11-23  0.33  0.34  0.33   0.34   34272000        0.0           0.0
# 1984-11-26  0.34  0.34  0.34   0.34   25160800        0.0           0.0
#
#               HL_PCT  PCT_change  SMA_1_days  EWMA_1_days  SMA_2_days  \
# Date
# 1980-12-12  0.000000    0.000000        0.41         0.41         NaN
# 1980-12-15  0.000000    0.000000        0.39         0.39       0.400
# 1980-12-16  0.000000    0.000000        0.36         0.36       0.375
# 1980-12-17  0.000000    0.000000        0.37         0.37       0.365
# 1980-12-18  0.000000    0.000000        0.38         0.38       0.375
# ...              ...         ...         ...          ...         ...
# 1984-11-19  6.451613   -6.060606        0.31         0.31       0.320
# 1984-11-20  0.000000    0.000000        0.32         0.32       0.315
# 1984-11-21  0.000000    0.000000        0.33         0.33       0.325
# 1984-11-23  0.000000    3.030303        0.34         0.34       0.335
# 1984-11-26  0.000000    0.000000        0.34         0.34       0.340
#
#             EWMA_2_days  SMA_4_days  EWMA_4_days  SMA_6_days  EWMA_6_days  \
# Date
# 1980-12-12     0.410000         NaN          NaN         NaN          NaN
# 1980-12-15     0.395000         NaN          NaN         NaN          NaN
# 1980-12-16     0.370769         NaN     0.378367         NaN          NaN
# 1980-12-17     0.370250      0.3825     0.374522         NaN          NaN
# 1980-12-18     0.376777      0.3750     0.376898         NaN     0.377932
# ...                 ...         ...          ...         ...          ...
# 1984-11-19     0.317694      0.3300     0.325392    0.331667     0.329914
# 1984-11-20     0.319231      0.3250     0.323235    0.328333     0.327081
# 1984-11-21     0.326410      0.3225     0.325941    0.328333     0.327915
# 1984-11-23     0.335470      0.3250     0.331565    0.328333     0.331368
# 1984-11-26     0.338490      0.3325     0.334939    0.328333     0.333834
#
#              UpperBB   LowerBB  ForceIndex
# Date
# 1980-12-12       NaN       NaN         NaN
# 1980-12-15       NaN       NaN   -879424.0
# 1980-12-16       NaN       NaN   -792960.0
# 1980-12-17       NaN       NaN    216104.0
# 1980-12-18       NaN       NaN    183624.0
# ...              ...       ...         ...
# 1984-11-19  0.376745  0.308255  -1164912.0
# 1984-11-20  0.376181  0.303819    658112.0
# 1984-11-21  0.374347  0.302320    446824.0
# 1984-11-23  0.365934  0.305732    342720.0
# 1984-11-26  0.354795  0.311872         0.0
#
# [1000 rows x 20 columns]

# %%
# Commodity Channel Index (CCI)
def CCI(data, days): 
    TP = (data['High'] + data['Low'] + data['Close']) / 3 
    CCI = pd.Series((TP - TP.rolling(window=days).mean()) / (0.015 * TP.rolling(window=days).std()))#, name = 'CCI')
    data['CCI'] = CCI
    return data
days = 2
CCI_ = CCI(hist, days)

# %%
hist.tail(100)
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits  \
# Date
# 2019-08-29  207.88  208.69  206.04  208.38  20990500        0.0           0.0
# 2019-08-30  209.53  209.82  206.58  208.12  21143400        0.0           0.0
# 2019-09-03  205.81  206.36  203.61  205.08  20023000        0.0           0.0
# 2019-09-04  207.77  208.85  206.70  208.56  19188100        0.0           0.0
# 2019-09-05  211.37  213.33  210.88  212.64  23913700        0.0           0.0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-01-15  311.85  315.50  309.55  311.34  30480900        0.0           0.0
# 2020-01-16  313.59  315.70  312.09  315.24  27207300        0.0           0.0
# 2020-01-17  316.27  318.74  315.00  318.73  34454100        0.0           0.0
# 2020-01-21  317.19  319.02  316.00  316.57  27710800        0.0           0.0
# 2020-01-22  318.58  319.99  317.31  317.70  25392800        0.0           0.0
#
#               HL_PCT  PCT_change  SMA_1_days  ...  SMA_2_days  EWMA_2_days  \
# Date                                          ...
# 2019-08-29  0.148767    0.240523      208.38  ...     206.645   207.149973
# 2019-08-30  0.816836   -0.672935      208.12  ...     208.250   207.796658
# 2019-09-03  0.624147   -0.354696      205.08  ...     206.600   205.985553
# 2019-09-04  0.139049    0.380228      208.56  ...     206.820   207.701851
# 2019-09-05  0.324492    0.600842      212.64  ...     210.600   210.993950
# ...              ...         ...         ...  ...         ...          ...
# 2020-01-15  1.336160   -0.163540      311.34  ...     312.010   311.975240
# 2020-01-16  0.145921    0.526165      315.24  ...     313.290   314.151747
# 2020-01-17  0.003137    0.777816      318.73  ...     316.985   317.203916
# 2020-01-21  0.773920   -0.195466      316.57  ...     317.650   316.781305
# 2020-01-22  0.720806   -0.276226      317.70  ...     317.135   317.393768
#
#             SMA_4_days  EWMA_4_days  SMA_6_days  EWMA_6_days     UpperBB  \
# Date
# 2019-08-29    205.6775   206.456613  206.093333   206.363355  214.119377
# 2019-08-30    206.2400   207.121968  205.476667   206.865253  214.166059
# 2019-09-03    206.6225   206.305181  205.985000   206.355181  213.657387
# 2019-09-04    207.5350   207.207108  206.433333   206.985129  213.857966
# 2019-09-05    208.6000   209.380265  207.948333   208.600807  214.671477
# ...                ...          ...         ...          ...         ...
# 2020-01-15    312.8275   311.408611  310.688333   309.769296  320.148234
# 2020-01-16    314.0550   312.941167  312.696667   311.332355  321.380674
# 2020-01-17    314.4975   315.256700  314.213333   313.445968  323.114115
# 2020-01-21    315.4700   315.782020  315.253333   314.338548  324.444529
# 2020-01-22    317.0600   316.549212  315.376667   315.298963  324.889168
#
#                LowerBB    ForceIndex        CCI
# Date
# 2019-08-29  198.742290  7.283703e+07  47.140452
# 2019-08-30  199.692274 -5.497284e+06  47.140452
# 2019-09-03  200.857613 -6.086992e+07 -47.140452
# 2019-09-04  201.103701  6.677459e+07  47.140452
# 2019-09-05  200.776856  9.756790e+07  47.140452
# ...                ...           ...        ...
# 2020-01-15  287.396766 -4.084441e+07 -47.140452
# 2020-01-16  290.117659  1.061085e+08  47.140452
# 2020-01-17  292.564219  1.202448e+08  47.140452
# 2020-01-21  293.937138 -5.985533e+07 -47.140452
# 2020-01-22  296.870832  2.869386e+07  47.140452
#
# [100 rows x 21 columns]

# %%
# Ease Of Movement (EVM)
def EVM(data, days): 
    dm = ((data['High'] + data['Low'])/2) - ((data['High'].shift(1) + data['Low'].shift(1))/2)
    br = (data['Volume'] / 100000000) / ((data['High'] - data['Low']))
    EVM = dm / br 
    EVM_MA = pd.Series(EVM.rolling(window=days).mean(), name = 'EVM') 
    data['EVM_MA'] = EVM_MA
    return data 
days = 1
EVM_ = EVM(hist, days)

# %%
hist.tail()
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits  \
# Date
# 2020-01-15  311.85  315.50  309.55  311.34  30480900        0.0           0.0
# 2020-01-16  313.59  315.70  312.09  315.24  27207300        0.0           0.0
# 2020-01-17  316.27  318.74  315.00  318.73  34454100        0.0           0.0
# 2020-01-21  317.19  319.02  316.00  316.57  27710800        0.0           0.0
# 2020-01-22  318.58  319.99  317.31  317.70  25392800        0.0           0.0
#
#               HL_PCT  PCT_change  SMA_1_days  ...  EWMA_2_days  SMA_4_days  \
# Date                                          ...
# 2020-01-15  1.336160   -0.163540      311.34  ...   311.975240    312.8275
# 2020-01-16  0.145921    0.526165      315.24  ...   314.151747    314.0550
# 2020-01-17  0.003137    0.777816      318.73  ...   317.203916    314.4975
# 2020-01-21  0.773920   -0.195466      316.57  ...   316.781305    315.4700
# 2020-01-22  0.720806   -0.276226      317.70  ...   317.393768    317.0600
#
#             EWMA_4_days  SMA_6_days  EWMA_6_days     UpperBB     LowerBB  \
# Date
# 2020-01-15   311.408611  310.688333   309.769296  320.148234  287.396766
# 2020-01-16   312.941167  312.696667   311.332355  321.380674  290.117659
# 2020-01-17   315.256700  314.213333   313.445968  323.114115  292.564219
# 2020-01-21   315.782020  315.253333   314.338548  324.444529  293.937138
# 2020-01-22   316.549212  315.376667   315.298963  324.889168  296.870832
#
#               ForceIndex        CCI     EVM_MA
# Date
# 2020-01-15 -4.084441e+07 -47.140452 -45.775387
# 2020-01-16  1.061085e+08  47.140452  18.177842
# 2020-01-17  1.202448e+08  47.140452  32.293689
# 2020-01-21 -5.985533e+07 -47.140452   6.974898
# 2020-01-22  2.869386e+07  47.140452  12.031757
#
# [5 rows x 22 columns]

# %%
# Rate of Change (ROC)
def ROC(data,days):
    N = data['Close'].diff(days)
    D = data['Close'].shift(days)
    roc = pd.Series(N/D,name='ROW')
    data = data.join(roc)
    return data 
days = 1
ROC_ = ROC(hist,days)

# %%
hist.tail()
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits  \
# Date
# 2020-01-15  311.85  315.50  309.55  311.34  30480900        0.0           0.0
# 2020-01-16  313.59  315.70  312.09  315.24  27207300        0.0           0.0
# 2020-01-17  316.27  318.74  315.00  318.73  34454100        0.0           0.0
# 2020-01-21  317.19  319.02  316.00  316.57  27710800        0.0           0.0
# 2020-01-22  318.58  319.99  317.31  317.70  25392800        0.0           0.0
#
#               HL_PCT  PCT_change  SMA_1_days  ...  EWMA_2_days  SMA_4_days  \
# Date                                          ...
# 2020-01-15  1.336160   -0.163540      311.34  ...   311.975240    312.8275
# 2020-01-16  0.145921    0.526165      315.24  ...   314.151747    314.0550
# 2020-01-17  0.003137    0.777816      318.73  ...   317.203916    314.4975
# 2020-01-21  0.773920   -0.195466      316.57  ...   316.781305    315.4700
# 2020-01-22  0.720806   -0.276226      317.70  ...   317.393768    317.0600
#
#             EWMA_4_days  SMA_6_days  EWMA_6_days     UpperBB     LowerBB  \
# Date
# 2020-01-15   311.408611  310.688333   309.769296  320.148234  287.396766
# 2020-01-16   312.941167  312.696667   311.332355  321.380674  290.117659
# 2020-01-17   315.256700  314.213333   313.445968  323.114115  292.564219
# 2020-01-21   315.782020  315.253333   314.338548  324.444529  293.937138
# 2020-01-22   316.549212  315.376667   315.298963  324.889168  296.870832
#
#               ForceIndex        CCI     EVM_MA
# Date
# 2020-01-15 -4.084441e+07 -47.140452 -45.775387
# 2020-01-16  1.061085e+08  47.140452  18.177842
# 2020-01-17  1.202448e+08  47.140452  32.293689
# 2020-01-21 -5.985533e+07 -47.140452   6.974898
# 2020-01-22  2.869386e+07  47.140452  12.031757
#
# [5 rows x 22 columns]

# %%
hist.fillna(-9999)
# Out:
#               Open    High     Low   Close     Volume  Dividends  \
# Date
# 1980-12-12    0.41    0.41    0.41    0.41  117258400        0.0
# 1980-12-15    0.39    0.39    0.39    0.39   43971200        0.0
# 1980-12-16    0.36    0.36    0.36    0.36   26432000        0.0
# 1980-12-17    0.37    0.37    0.37    0.37   21610400        0.0
# 1980-12-18    0.38    0.38    0.38    0.38   18362400        0.0
# ...            ...     ...     ...     ...        ...        ...
# 2020-01-15  311.85  315.50  309.55  311.34   30480900        0.0
# 2020-01-16  313.59  315.70  312.09  315.24   27207300        0.0
# 2020-01-17  316.27  318.74  315.00  318.73   34454100        0.0
# 2020-01-21  317.19  319.02  316.00  316.57   27710800        0.0
# 2020-01-22  318.58  319.99  317.31  317.70   25392800        0.0
#
#             Stock Splits    HL_PCT  PCT_change  SMA_1_days  ...  EWMA_2_days  \
# Date                                                        ...
# 1980-12-12           0.0  0.000000    0.000000        0.41  ...     0.410000
# 1980-12-15           0.0  0.000000    0.000000        0.39  ...     0.395000
# 1980-12-16           0.0  0.000000    0.000000        0.36  ...     0.370769
# 1980-12-17           0.0  0.000000    0.000000        0.37  ...     0.370250
# 1980-12-18           0.0  0.000000    0.000000        0.38  ...     0.376777
# ...                  ...       ...         ...         ...  ...          ...
# 2020-01-15           0.0  1.336160   -0.163540      311.34  ...   311.975240
# 2020-01-16           0.0  0.145921    0.526165      315.24  ...   314.151747
# 2020-01-17           0.0  0.003137    0.777816      318.73  ...   317.203916
# 2020-01-21           0.0  0.773920   -0.195466      316.57  ...   316.781305
# 2020-01-22           0.0  0.720806   -0.276226      317.70  ...   317.393768
#
#             SMA_4_days  EWMA_4_days   SMA_6_days  EWMA_6_days      UpperBB  \
# Date
# 1980-12-12  -9999.0000 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 1980-12-15  -9999.0000 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 1980-12-16  -9999.0000     0.378367 -9999.000000 -9999.000000 -9999.000000
# 1980-12-17      0.3825     0.374522 -9999.000000 -9999.000000 -9999.000000
# 1980-12-18      0.3750     0.376898 -9999.000000     0.377932 -9999.000000
# ...                ...          ...          ...          ...          ...
# 2020-01-15    312.8275   311.408611   310.688333   309.769296   320.148234
# 2020-01-16    314.0550   312.941167   312.696667   311.332355   321.380674
# 2020-01-17    314.4975   315.256700   314.213333   313.445968   323.114115
# 2020-01-21    315.4700   315.782020   315.253333   314.338548   324.444529
# 2020-01-22    317.0600   316.549212   315.376667   315.298963   324.889168
#
#                 LowerBB    ForceIndex          CCI       EVM_MA
# Date
# 1980-12-12 -9999.000000 -9.999000e+03 -9999.000000 -9999.000000
# 1980-12-15 -9999.000000 -8.794240e+05   -47.140452     0.000000
# 1980-12-16 -9999.000000 -7.929600e+05   -47.140452     0.000000
# 1980-12-17 -9999.000000  2.161040e+05    47.140452     0.000000
# 1980-12-18 -9999.000000  1.836240e+05    47.140452     0.000000
# ...                 ...           ...          ...          ...
# 2020-01-15   287.396766 -4.084441e+07   -47.140452   -45.775387
# 2020-01-16   290.117659  1.061085e+08    47.140452    18.177842
# 2020-01-17   292.564219  1.202448e+08    47.140452    32.293689
# 2020-01-21   293.937138 -5.985533e+07   -47.140452     6.974898
# 2020-01-22   296.870832  2.869386e+07    47.140452    12.031757
#
# [9860 rows x 22 columns]
